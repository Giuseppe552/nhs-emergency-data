# %%
import sys
import os

# Add src folder to the path
src_path = os.path.abspath('./src')
sys.path.append(src_path)

print("src path:", src_path)
print("Exists:", os.path.exists(src_path))
print("Files in src:", os.listdir(src_path))
# Out:
# src path: C:\Users\hello\nhs-wait-times\src
# Exists: True
# Files in src: ['.ipynb_checkpoints', 'load_clean.py', 'Untitled.ipynb', '__pycache__']

# %%
from load_clean import load_and_clean

df = load_and_clean('./data/raw/Monthly-AE-Time-Series-June-2025-1-1.xls')
df.head()
# Out:
# ORIGINAL COLUMNS: ['Period', 'Type 1 Departments - Major A&E', 'Type 2 Departments - Single Specialty', 'Type 3 Departments - Other A&E/Minor Injury Unit', 'Total Attendances', 'Emergency Admissions via Type 1 A&E', 'Emergency Admissions via Type 2 A&E', 'Emergency Admissions via Type 3 and 4 A&E', 'Total Emergency Admissions via A&E', 'Other Emergency Admissions (i.e not via A&E)', 'Total Emergency Admissions', 'Number of patients spending >4 hours from decision to admit to admission', 'Number of patients spending >12 hours from decision to admit to admission', 'Operational standard (Performance)']
# CLEANED COLUMNS: ['period', 'type_1_departments_-_major_a&e', 'type_2_departments_-_single_specialty', 'type_3_departments_-_other_a&e/minor_injury_unit', 'total_attendances', 'emergency_admissions_via_type_1_a&e', 'emergency_admissions_via_type_2_a&e', 'emergency_admissions_via_type_3_and_4_a&e', 'total_emergency_admissions_via_a&e', 'other_emergency_admissions_(i.e_not_via_a&e)', 'total_emergency_admissions', 'number_of_patients_spending_>4_hours_from_decision_to_admit_to_admission', 'number_of_patients_spending_>12_hours_from_decision_to_admit_to_admission', 'operational_standard_(performance)']
#       period  type_1_departments_-_major_a&e  \
# 0 2010-08-01                    1.138652e+06
# 1 2010-09-01                    1.150728e+06
# 2 2010-10-01                    1.163143e+06
# 3 2010-11-01                    1.111295e+06
# 4 2010-12-01                    1.159204e+06
#
#    type_2_departments_-_single_specialty  \
# 0                           54371.000000
# 1                           55181.000000
# 2                           54961.000000
# 3                           53727.428571
# 4                           45536.428571
#
#    type_3_departments_-_other_a&e/minor_injury_unit  total_attendances  \
# 0                                     559358.000000       1.752381e+06
# 1                                     550359.000000       1.756268e+06
# 2                                     583244.000000       1.801348e+06
# 3                                     486005.428571       1.651027e+06
# 4                                     533000.857143       1.737741e+06
#
#    emergency_admissions_via_type_1_a&e  emergency_admissions_via_type_2_a&e  \
# 0                        287438.000000                          5367.000000
# 1                        293991.000000                          5543.000000
# 2                        303452.000000                          5485.000000
# 3                        297832.000000                          5731.142857
# 4                        318602.428571                          6277.000000
#
#    emergency_admissions_via_type_3_and_4_a&e  \
# 0                                8081.000000
# 1                                3673.000000
# 2                                2560.000000
# 3                                3279.000000
# 4                                3198.428571
#
#    total_emergency_admissions_via_a&e  \
# 0                       300886.000000
# 1                       303207.000000
# 2                       311497.000000
# 3                       306842.142857
# 4                       328077.857143
#
#    other_emergency_admissions_(i.e_not_via_a&e)  total_emergency_admissions  \
# 0                                 124816.000000               425702.000000
# 1                                 121693.000000               424900.000000
# 2                                 124718.000000               436215.000000
# 3                                 122256.857143               429099.000000
# 4                                 124650.857143               452728.714286
#
#    number_of_patients_spending_>4_hours_from_decision_to_admit_to_admission  \
# 0                                        3697.000000
# 1                                        5907.000000
# 2                                        6932.000000
# 3                                        7179.000000
# 4                                       13818.142857
#
#    number_of_patients_spending_>12_hours_from_decision_to_admit_to_admission  \
# 0                                                1.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                               15.0
#
#    operational_standard_(performance)
# 0                                0.95
# 1                                0.95
# 2                                0.95
# 3                                0.95
# 4                                0.95

# %%
   print(df.columns.tolist())
# Out:
# ['period', 'type_1_departments_-_major_a&e', 'type_2_departments_-_single_specialty', 'type_3_departments_-_other_a&e/minor_injury_unit', 'total_attendances', 'emergency_admissions_via_type_1_a&e', 'emergency_admissions_via_type_2_a&e', 'emergency_admissions_via_type_3_and_4_a&e', 'total_emergency_admissions_via_a&e', 'other_emergency_admissions_(i.e_not_via_a&e)', 'total_emergency_admissions', 'number_of_patients_spending_>4_hours_from_decision_to_admit_to_admission', 'number_of_patients_spending_>12_hours_from_decision_to_admit_to_admission', 'operational_standard_(performance)']

# %%
 print(df.head())
# Out:
#       period  type_1_departments_-_major_a&e  \
# 0 2010-08-01                    1.138652e+06
# 1 2010-09-01                    1.150728e+06
# 2 2010-10-01                    1.163143e+06
# 3 2010-11-01                    1.111295e+06
# 4 2010-12-01                    1.159204e+06
#
#    type_2_departments_-_single_specialty  \
# 0                           54371.000000
# 1                           55181.000000
# 2                           54961.000000
# 3                           53727.428571
# 4                           45536.428571
#
#    type_3_departments_-_other_a&e/minor_injury_unit  total_attendances  \
# 0                                     559358.000000       1.752381e+06
# 1                                     550359.000000       1.756268e+06
# 2                                     583244.000000       1.801348e+06
# 3                                     486005.428571       1.651027e+06
# 4                                     533000.857143       1.737741e+06
#
#    emergency_admissions_via_type_1_a&e  emergency_admissions_via_type_2_a&e  \
# 0                        287438.000000                          5367.000000
# 1                        293991.000000                          5543.000000
# 2                        303452.000000                          5485.000000
# 3                        297832.000000                          5731.142857
# 4                        318602.428571                          6277.000000
#
#    emergency_admissions_via_type_3_and_4_a&e  \
# 0                                8081.000000
# 1                                3673.000000
# 2                                2560.000000
# 3                                3279.000000
# 4                                3198.428571
#
#    total_emergency_admissions_via_a&e  \
# 0                       300886.000000
# 1                       303207.000000
# 2                       311497.000000
# 3                       306842.142857
# 4                       328077.857143
#
#    other_emergency_admissions_(i.e_not_via_a&e)  total_emergency_admissions  \
# 0                                 124816.000000               425702.000000
# 1                                 121693.000000               424900.000000
# 2                                 124718.000000               436215.000000
# 3                                 122256.857143               429099.000000
# 4                                 124650.857143               452728.714286
#
#    number_of_patients_spending_>4_hours_from_decision_to_admit_to_admission  \
# 0                                        3697.000000
# 1                                        5907.000000
# 2                                        6932.000000
# 3                                        7179.000000
# 4                                       13818.142857
#
#    number_of_patients_spending_>12_hours_from_decision_to_admit_to_admission  \
# 0                                                1.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                               15.0
#
#    operational_standard_(performance)
# 0                                0.95
# 1                                0.95
# 2                                0.95
# 3                                0.95
# 4                                0.95

# %%
   # Look for similar column names
   [col for col in df.columns if 'period' in col.lower()]
# Out:
# ['period']

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

plt.figure(figsize=(12, 6))
plt.plot(df['period'], df['total_attendances'])

plt.title('Total A&E Attendances Over Time')
plt.xlabel('Date')
plt.ylabel('Total Attendances (millions)')

# Format y-axis ticks to show millions
plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{x*1e-6:.1f}M'))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.describe().T
# Out:
#                                                     count  \
# period                                                179
# type_1_departments_-_major_a&e                      179.0
# type_2_departments_-_single_specialty               179.0
# type_3_departments_-_other_a&e/minor_injury_unit    179.0
# total_attendances                                   179.0
# emergency_admissions_via_type_1_a&e                 179.0
# emergency_admissions_via_type_2_a&e                 179.0
# emergency_admissions_via_type_3_and_4_a&e           179.0
# total_emergency_admissions_via_a&e                  179.0
# other_emergency_admissions_(i.e_not_via_a&e)        179.0
# total_emergency_admissions                          179.0
# number_of_patients_spending_>4_hours_from_decis...  179.0
# number_of_patients_spending_>12_hours_from_deci...  179.0
# operational_standard_(performance)                   87.0
#
#                                                                              mean  \
# period                                              2017-12-31 04:17:25.810055936
# type_1_departments_-_major_a&e                                     1260806.340782
# type_2_departments_-_single_specialty                                47319.164405
# type_3_departments_-_other_a&e/minor_injury_unit                    643867.446927
# total_attendances                                                  1951992.952115
# emergency_admissions_via_type_1_a&e                                 353843.910615
# emergency_admissions_via_type_2_a&e                                   1684.005587
# emergency_admissions_via_type_3_and_4_a&e                             4123.217877
# total_emergency_admissions_via_a&e                                  359651.134078
# other_emergency_admissions_(i.e_not_via_a&e)                        125630.413408
# total_emergency_admissions                                          485281.547486
# number_of_patients_spending_>4_hours_from_decis...                   60892.871508
# number_of_patients_spending_>12_hours_from_deci...                     9199.03352
# operational_standard_(performance)                                           0.95
#
#                                                                     min  \
# period                                              2010-08-01 00:00:00
# type_1_departments_-_major_a&e                                 689720.0
# type_2_departments_-_single_specialty                           19726.0
# type_3_departments_-_other_a&e/minor_injury_unit               207129.0
# total_attendances                                              916575.0
# emergency_admissions_via_type_1_a&e                            252680.0
# emergency_admissions_via_type_2_a&e                               960.0
# emergency_admissions_via_type_3_and_4_a&e                   2145.142857
# total_emergency_admissions_via_a&e                             257928.0
# other_emergency_admissions_(i.e_not_via_a&e)                    68653.0
# total_emergency_admissions                                     326581.0
# number_of_patients_spending_>4_hours_from_decis...               3697.0
# number_of_patients_spending_>12_hours_from_deci...                  0.0
# operational_standard_(performance)                                 0.95
#
#                                                                     25%  \
# period                                              2014-04-16 00:00:00
# type_1_departments_-_major_a&e                           1197298.285714
# type_2_departments_-_single_specialty                           43663.0
# type_3_departments_-_other_a&e/minor_injury_unit          577745.357143
# total_attendances                                        1829944.785714
# emergency_admissions_via_type_1_a&e                            322154.5
# emergency_admissions_via_type_2_a&e                              1225.5
# emergency_admissions_via_type_3_and_4_a&e                   3363.714286
# total_emergency_admissions_via_a&e                        327026.285714
# other_emergency_admissions_(i.e_not_via_a&e)              120495.428571
# total_emergency_admissions                                447266.785714
# number_of_patients_spending_>4_hours_from_decis...         17548.714286
# number_of_patients_spending_>12_hours_from_deci...                 26.5
# operational_standard_(performance)                                 0.95
#
#                                                                     50%  \
# period                                              2018-01-01 00:00:00
# type_1_departments_-_major_a&e                                1258205.0
# type_2_departments_-_single_specialty                           49233.0
# type_3_departments_-_other_a&e/minor_injury_unit          628214.285714
# total_attendances                                             1949762.0
# emergency_admissions_via_type_1_a&e                            356160.0
# emergency_admissions_via_type_2_a&e                              1353.0
# emergency_admissions_via_type_3_and_4_a&e                        4164.0
# total_emergency_admissions_via_a&e                             360998.0
# other_emergency_admissions_(i.e_not_via_a&e)                   125656.0
# total_emergency_admissions                                     484952.0
# number_of_patients_spending_>4_hours_from_decis...         45982.142857
# number_of_patients_spending_>12_hours_from_deci...                252.0
# operational_standard_(performance)                                 0.95
#
#                                                                     75%  \
# period                                              2021-09-16 00:00:00
# type_1_departments_-_major_a&e                                1351789.5
# type_2_departments_-_single_specialty                      52106.857143
# type_3_departments_-_other_a&e/minor_injury_unit               731001.0
# total_attendances                                             2124390.0
# emergency_admissions_via_type_1_a&e                            384714.5
# emergency_admissions_via_type_2_a&e                         1624.214286
# emergency_admissions_via_type_3_and_4_a&e                        4839.0
# total_emergency_admissions_via_a&e                             390422.0
# other_emergency_admissions_(i.e_not_via_a&e)              132333.285714
# total_emergency_admissions                                     524757.0
# number_of_patients_spending_>4_hours_from_decis...             106556.5
# number_of_patients_spending_>12_hours_from_deci...               6041.0
# operational_standard_(performance)                                 0.95
#
#                                                                     max  \
# period                                              2025-06-01 00:00:00
# type_1_departments_-_major_a&e                                1472721.0
# type_2_departments_-_single_specialty                      58574.285714
# type_3_departments_-_other_a&e/minor_injury_unit               892325.0
# total_attendances                                             2416292.0
# emergency_admissions_via_type_1_a&e                            420025.0
# emergency_admissions_via_type_2_a&e                              6277.0
# emergency_admissions_via_type_3_and_4_a&e                        8081.0
# total_emergency_admissions_via_a&e                             426154.0
# other_emergency_admissions_(i.e_not_via_a&e)                   147086.0
# total_emergency_admissions                                     567456.0
# number_of_patients_spending_>4_hours_from_decis...             170121.0
# number_of_patients_spending_>12_hours_from_deci...              61529.0
# operational_standard_(performance)                                 0.95
#
#                                                               std
# period                                                        NaN
# type_1_departments_-_major_a&e                      119628.018516
# type_2_departments_-_single_specialty                 6972.855358
# type_3_departments_-_other_a&e/minor_injury_unit    114837.322332
# total_attendances                                   232116.758202
# emergency_admissions_via_type_1_a&e                  37345.932099
# emergency_admissions_via_type_2_a&e                    934.785415
# emergency_admissions_via_type_3_and_4_a&e             1233.098372
# total_emergency_admissions_via_a&e                   37799.622834
# other_emergency_admissions_(i.e_not_via_a&e)         10887.653839
# total_emergency_admissions                           45937.778564
# number_of_patients_spending_>4_hours_from_decis...   48231.516472
# number_of_patients_spending_>12_hours_from_deci...   16495.888579
# operational_standard_(performance)                            0.0

# %%
missing = df.isnull().sum()
print("Missing values per column:\n", missing[missing > 0])
# Out:
# Missing values per column:
#  operational_standard_(performance)    92
# dtype: int64

# %% [markdown]
# ## Step 1: Load & Inspect Data
#
# We load the Excel file and display the first few rows. This data includes monthly A&E attendance and emergency admissions across England from August 2010 to June 2025.

# %% [markdown]
# ## Step 2: Clean Column Names
#
# To simplify analysis, we:
# - Dropped fully empty rows and columns
# - Normalized column names (lowercase, replaced spaces with underscores)
# - Parsed dates from the `Period` column
